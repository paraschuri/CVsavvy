# %%
import fitz

# %%
# !pip install docxpy
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for docxpy: filename=docxpy-0.8.5-py3-none-any.whl size=5003 sha256=32fcd59dd15bddd24221e0eec18a6c64d90b801aff0999bb88211263c719ed9e
#   Stored in directory: c:\users\paras\appdata\local\pip\cache\wheels\25\41\f3\7ea75e309596711f8ac77ac3f08682710a6ce4b3e3ac3b72fe
# Successfully built docxpy
# ...

# %%
import docxpy
file = 'E:\Download\sample3pdf.docx'

# extract text
text = docxpy.process(file)

# %%
text =
# Out:
# 'Ruchika Shirsath\n\n\n\n\n\nEducation\n\n\t\n8169150224   ruchikashirsath2003@gmail.com\t LinkedIn     GitHub\n\n\n\n\tVeermata Jijabai Technological Institute\t2021 – 2025\n\n\tB.Tech in Information Technology\tMumbai, India\n\nCGPA - 9.205\n\n\tBhavani Shankar Junior College\t2019 – 2021\n\n\tHSC: 93.6% , MHTCET: 99.7989 percentile\tMumbai, India\n\nRelevant Coursework\n\n\n\n\tData Structures\n\n\tAlgorithm Analysis\n\n\tOperating Systems\n\nProjects\n\n\t\nComputer Organization and Architecture\n\n\t\nDatabase Management\n\n\tLinear Algebra\n\n\tDiscrete Mathematics\n\n\t\nJava\n\n\tC++\n\n\n\n\n\n\t\tIntelligent Navigesture\t| OpenCV , HTML ,CSS , JS , React , DOM\tOct 22 – Feb 23\n\n\n\n\tUtilizing OpenCV’s computer vision algorithms to accurately interpret user gestures, enabling actions like clicking, scrolling, tapping, and drawing.\n\n\tIncorporating modern UI/UX paradigms with HTML, CSS, JS, and React, creating an adaptive and immersive gesture-based browsing experience.\
# ...

# %%
f = open("E:\Download\sample3pdf.docx")

# %%
file = fitz.open(f)
resume_text = get_text(file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\paras\anaconda3\Lib\site-packages\fitz\__init__.py:2642, in Document.__init__(self, filename, stream, filetype, rect, width, height, fontsize)
#    2641 try:
# -> 2642     self.this = extra.Document_init( filename, stream, filetype, rect, width, height, fontsize)
#    2643 except Exception as e:
#
# File c:\Users\paras\anaconda3\Lib\site-packages\fitz\extra.py:153, in Document_init(filename, stream, filetype, rect, width, height, fontsize)
#     152 def Document_init(filename, stream, filetype, rect, width, height, fontsize):
# --> 153     return _extra.Document_init(filename, stream, filetype, rect, width, height, fontsize)
#
# RuntimeError: code=2: cannot find fixed document sequence start part
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import requests

# %%
res = requests.get("http://api.glassdoor.com/api/api.htm?v=1.1&format=json&t.p=120&t.k=fz6JLNDfgVs&action=job&q=software&userip=192.168.43.42&useragent=Mozilla/%2F4.0")

# %%
res
# Out:
# <Response [403]>

# %%
driver = webdriver.Chrome()
driver.get("https://www.glassdoor.com/Job/india-{}-jobs-SRCH_IL.0,5_IN115_KO6,{}.htm".format(user_domain,len(user_domain)+6))
resp = driver.page_source
soup=BeautifulSoup(resp,'html.parser')
allJobsContainer = soup.find("ul",{"class":"JobsList_jobsList__Ey2Vo"})
allJobs = allJobsContainer.find_all("li")
l = []
o = {}
for job in allJobs:
    try:
        name = job.find("span",{"class":"EmployerProfile_employerName__8w0tV"}).text
        if name[-1].isdigit():
            name = name[:-3]
        o["company"] = name
    except:
        o["company"]=None
    try:
        o["job"]=job.find("a",{"class":"JobCard_jobTitle__rbjTE"}).text
    except:
        o["job"]=None
    try:
        o["location"]=job.find("div",{"data-test":"emp-location"}).text
    except:
        o["location"]=None
    try:
        salary = job.find("div",{"data-test":"detailSalary"}).text
        salary = salary.split('\xa0')
        salary = ' '.join(salary[:-1])
        salary = salary.split(' ')
        processed_salary = 0
        for i in salary:
            if i[0].isdigit():
                if i[-1]=='K':
                    processed_salary += int(i[:-1])*1000
                elif i[-1]=='M':
                    processed_salary += int(i[:-1])*1000000
        o["salary"]="INR "+str(processed_salary//2)
    except:
        o["salary"]=None
    try:
        link = job.find("a",{"class":"JobCard_jobTitle__rbjTE"})
        o["apply"]= link["href"]
    except:
        o["apply"]=None
    try:
        logo = job.find("img")
        o["logo"] = logo["src"]
    except:
        o["logo"] = None
    # if o["company"]:
    l.append(o)
    o={}

# %%
l
# Out:
# [{'company': 'Deccansoft Software Services',
#   'job': 'Web Developer',
#   'location': 'Hyderābād',
#   'salary': 'INR 369000',
#   'apply': 'https://www.glassdoor.co.in/job-listing/web-developer-deccansoft-software-services-JV_IC2865319_KO0,13_KE14,42.htm?jl=1009067576847',
#   'logo': None},
#  {'company': 'Peertechz',
#   'job': 'Web developer',
#   'location': 'India',
#   'salary': 'INR 13000',
#   'apply': 'https://www.glassdoor.co.in/job-listing/web-developer-peertechz-JV_KO0,13_KE14,23.htm?jl=1009115972235',
#   'logo': 'https://media.glassdoor.com/sql/2338018/peertechz-squarelogo-1630069039601.png'},
#  {'company': 'Wibits Web Solutions',
#   'job': 'Web Developer – Intern',
#   'location': 'Nagercoil',
#   'salary': None,
#   'apply': 'https://www.glassdoor.co.in/job-listing/web-developer-intern-wibits-web-solutions-JV_IC2833221_KO0,20_KE21,41.htm?jl=1008920088570',
#   'logo': 'https://media.glassdoor.com/sql/3188665/wibits-web-solutions-squarelogo-1590123485230.png'},
# ...

# %%
import requests

url = "https://auth.emsicloud.com/connect/token"

payload = "client_id=13v71rzh0iukub2m&client_secret=fTe1ESGO&grant_type=client_credentials&scope=emsi_open"
headers = {'Content-Type': 'application/x-www-form-urlencoded'}

response = requests.request("POST", url, data=payload, headers=headers)

res = response.json()

# %%
token = res["access_token"]
token
# Out:
# 'eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..qlOkIDy1nPwDqumaMXqOEtWdbq1OZsr-AB4JrFJbJvhQbqPzlPVga4GAWZlBFyU1QikZtv2mavZndYAu36hHcw7aiDzCRt4t7n1ExFcLNv2uf3LYKtKnZuiDxJG7Z0-VNOr-VdN7ykZlDfrodwkdAu8mOUUsiEYy8tTT5jEcLwap4nCMV-mq2WSPoTVi5hsCaVpXq5qgl3h6CZoHWVJgvIXrPSP1qETelHE_edK3kuLU3mC0dx11pEjQQK8NdFOHsySQ_qRNzmJG0DdfVg5x4igyhCaLzcidQsi77pUr7s0CSDU-MnJfJFsFTIJc2-3dmxZ0TxK-eq6uPRGD0OOkfA'

# %%
import requests

url = "https://emsiservices.com/skills/versions/latest/skills"

headers = {"Authorization": f"Bearer {token}"}
params = {
    "q":"datascience",
    "typeIds":"ST1,ST2",
    "fields":"id,name,type,infoUrl",
    "limit":"100"
}
response = requests.request("GET", url, headers=headers,params=params)

print(response.text)
# Out:
# {"attributions": [{"name": "Wikipedia", "text": "Wikipedia extracts are distributed under the CC BY-SA license (https://creativecommons.org/licenses/by-sa/3.0/)"}], "data": []}

# %%
import requests 
from bs4 import BeautifulSoup

# %%
headers={
    "User-Agent":"PostmanRuntime/7.36.1",
    "Cookie":'''CSRF=ewSzZfUVKSoWD0WtiZiibgKDLtsnNfpS; CTK=1hm4b7n7rkc0u800; RF="QXOA6F_NPhMGVlv7ATjDOyLmqdFlqOPl0QbOY-p2Q4PhOET7OqB6EnDOwnLqSxFan8WbNy_mC9g="; __cf_bm=qtQSt.24moLw_TIDVHoz2RlsK_ovLurot3kbFkCEB.E-1707456311-1-ARJketiz9mbP9cp8qsyvbaB/xSAdmGBg9MKphZNLE9TOR3JgKem5TmFepm3029dw0BwrQ8g14PIKPJQkrn5t6xQ=; _cfuvid=SFFntv7.6qgOvFjuIVMOFJQNFaI5X4Vozx64Ig5pdcI-1707456311228-0-604800000; INDEED_CSRF_TOKEN=HR6YmBWfygaD01Vnm8wmytvFc7URJWCB; LV="LA=1707456354:LV=1707422168:CV=1707456354:TS=1707422168"; PREF="TM=1707456354964:L=Pune%2C+Maharashtra"; RQ="q=web+developer&l=Pune%2C+Maharashtra&ts=1707456354971:q=web+developer&l=&ts=1707422300068"; hpnode=1; indeed_rcc="LV:RQ''',

}
r = requests.get("https://in.indeed.com/jobs?q=web%20developer&l=Pune%2C%20Maharashtra&from=searchOnHP",headers=headers)

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <link href="/images/favicon.ico" rel="shortcut icon"/>
# <title>1,952 Web Developer Jobs and Vacancies in Pune, Maharashtra - 9 February 2024 | Indeed.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="1,952 Web Developer jobs available in Pune, Maharashtra on Indeed.com. Apply to Web Developer, Full Stack Developer, Developer and more!" name="description"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <link href="/jobs?q=web+developer&amp;l=Pune%2C+Maharashtra&amp;from=searchOnHP&amp;jlid=dd616958bd9ddc12&amp;forceLocation=-1&amp;start=10" rel="next"/>
# <link href="https://in.indeed.com/q-web-developer-l-pune,-maharashtra-jobs.html" rel="canonical"/>
# <link href="android-app://com.indeed.android.jobsearch/https/in.indeed.com/m/jobs?q=web+developer&amp;l=Pune%2C+Maharashtra&amp;from=searchOnHP" rel="alternate"/>
# ...

# %%
data= soup.find("ul",{"class":"eu4oa1w0"})

# %%
data = data.find_all("li")

# %%
for job in data:
    print(job)
    try:
        name = job.find("a",{"class":"jcs-JobTitle"}).find("span").text
        print(name)
    except:
        print()
# Out:
# <li class="css-kyg8or eu4oa1w0"><div class="yosegi-FilterPill-dropdownPillContainer"><button aria-controls="filter-dateposted-menu" aria-expanded="false" aria-haspopup="menu" aria-label="Date posted filter" class="yosegi-FilterPill-pill" id="filter-dateposted"><div class="yosegi-FilterPill-pillLabel">Date posted</div><div class="yosegi-FilterPill-pillIcon"><svg aria-hidden="true" height="12px" viewbox="0 0 14 14" width="12px"><g><path d="M5,5l4,4,4-4H5Z"></path></g></svg></div></button><ul class="yosegi-FilterPill-dropdownList" id="filter-dateposted-menu" role="menu"><li class="yosegi-FilterPill-dropdownListItem" role="menuitem" tabindex="-1"><a class="yosegi-FilterPill-dropdownListItemLink" href="/jobs?q=web+developer&amp;l=Pune%2C+Maharashtra&amp;fromage=1" tabindex="-1">Last 24 hours</a></li><li class="yosegi-FilterPill-dropdownListItem" role="menuitem" tabindex="-1"><a class="yosegi-FilterPill-dropdownListItemLink" href="/jobs?q=web+developer&amp;l=Pune%2C+Maharashtra&amp;fromage
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
user_domain='web-developer'
driver = webdriver.Chrome()
driver.get("https://www.glassdoor.com/Job/india-{}-jobs-SRCH_IL.0,5_IN115_KO6,{}.htm".format(user_domain,len(user_domain)+6))
resp = driver.page_source
soup=BeautifulSoup(resp,'html.parser')

# %%
soup
# Out:
# <html class="fonts-loaded-initial fonts-loaded-full" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NZVNV6T&amp;l=gdGlobals"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=cdf4795650849dec6ff6cdea81dab02b"></script><script async="" src="https://unpkg.com/web-vitals/dist/web-vitals.iife.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" data-isnonnativesdk="true" data-loader="RS_JS_SDK" id="Optimizely_RS" src="https://cdn.rudderlabs.com/v1.1/js-integrations/Optimizely.min.js" type="text/javascript"></script><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><title>21,445 web developer Jobs in India, February 202
# ...
